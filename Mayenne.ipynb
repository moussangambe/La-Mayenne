# %%
import pandas as pd
# !jupyter nbconvert --to script Mayenne.ipynb
# Lire les fichier Excel
df2019 = pd.read_excel('/Users/moussangambe/Desktop/Mayenne/Donées/data.gouv-cd53-2019.xlsx',header =0)
df2020 = pd.read_excel('/Users/moussangambe/Desktop/Mayenne/Donées/data.gouv-cd53-2020.xlsx',header =0)
df2021 = pd.read_excel('/Users/moussangambe/Desktop/Mayenne/Donées/data.gouv-cd53-2021.xlsx',header =0)
df2022 = pd.read_excel('/Users/moussangambe/Desktop/Mayenne/Donées/donnees-essentielles-de-subvention (1).xlsx',header =0)
# Out:
# [NbConvertApp] Converting notebook Mayenne.ipynb to script
# [NbConvertApp] Writing 13296 bytes to Mayenne.py
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
df2022
# Out:
#                           nomAttribuant    idAttribuant       dateConvention  \
# 0   Conseil Départemental de la Mayenne  22530001100015  2021-06-14 00:00:00
# 1   Conseil Départemental de la Mayenne  22530001100015  2022-01-05 00:00:00
# 2   Conseil Départemental de la Mayenne  22530001100015  2022-01-10 00:00:00
# 3   Conseil Départemental de la Mayenne  22530001100015  2022-01-13 00:00:00
# 4   Conseil Départemental de la Mayenne  22530001100015  2022-01-24 00:00:00
# ..                                  ...             ...                  ...
# 94  Conseil Départemental de la Mayenne  22530001100015  2001-09-24 00:00:00
# 95  Conseil Départemental de la Mayenne  22530001100015  2001-09-24 00:00:00
# 96  Conseil Départemental de la Mayenne  22530001100015  2021-12-10 00:00:00
# 97  Conseil Départemental de la Mayenne  22530001100015  2021-12-10 00:00:00
# 98  Conseil Départemental de la Mayenne  22530001100015  2022-05-18 00:00:00
#
#    referenceDecision                                    nomBénéficiaire  \
# 0         2021-06-07     ASS PARRAINS PAR MILLE  ASS PARRAINS PAR MILLE
# 1         2021-12-10  BANQUE ALIMENTAIRE DE LA MAY  BANQUE ALIMENTAI...
# 2         2021-12-06                         ASSOCIATION LES DEUX RIVES
# 3         2022-01-03                                               UDAF
# 4         2022-01-03  ASSOCIATION DEPARTEMENTALE POUR LE LOGEMENT DE...
# ..               ...                                                ...
# 94        2021-12-09  COLLEGE PRIVE NOTRE DAME OGEC SAINT PIERRE LA ...
# 95        2021-12-09                       COLLEGE PRIVE SAINT NICOLAS
# 96        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 97        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 98        2022-03-07  L'AMICALE DU PERSONNEL DU CONSEIL DEPÄRTEMENTA...
#
#     idBeneficiaire                                              objet  \
# 0   39981222100048  Mise en œuvre d'actions de parrainage en direc...
# 1   39297142000022  Soutien technique et financier du Département ...
# 2   39313886200015  Partenariat entre le Département et l'associat...
# 3   77559377500031  UDAF met en place sur l'ensemble du départemen...
# 4   84223890900019  L'ADLJ met en place sur l'ensemble du départem...
# ..             ...                                                ...
# 94  78627559400046                                 Forfait d'Externat
# 95  78627883800044                                 Forfait d'Externat
# 96  47891394000019  4 axes sanitaires pour la protection des élevages
# 97  47891394000019                               prophylaxie annuelle
# 98  53099947300016                                      Arbre de Noël
#
#      montant             nature  \
# 0   330000.0  Aide en numéraire
# 1    50000.0  Aide en numéraire
# 2   120000.0  Aide en numéraire
# 3   153000.0  Aide en numéraire
# 4   187500.0  Aide en numéraire
# ..       ...                ...
# 94  231592.0  Aide en numéraire
# 95  127334.0  Aide en numéraire
# 96   42000.0  Aide en numéraire
# 97  112000.0  Aide en numéraire
# 98   74200.0  Aide en numéraire
#
#                                   conditionsVersement conditionsVersement.1  \
# 0   Convention pour 3 ans du 21/06/2021 au 20/06/2...             échelonné
# 1   Convention pour 1 an\nVersement en une seule f...                unique
# 2   Convention pour 2 ans du 01/01/22 au 31/12/23 ...             échelonné
# 3   Convention pour 3 ans du 01/01/2022 au 31/12/2...             échelonné
# 4   Convention pour 3 ans du 01/01/2022 au 31/12/2...             échelonné
# ..                                                ...                   ...
# 94                                        En une fois                unique
# 95                                        En une fois                unique
# 96  participation versée en une fois, sur présenta...                unique
# 97  participation versée au GDS sur présentation d...                unique
# 98   Cette subvention est composée de deux parts, ...                unique
#
#                   datePremierVersement               dateDeuxiemeVersement  \
# 0   17/09/2021\n30/06/2022\n30/06/2023                                 NaN
# 1                  2022-01-18 00:00:00                                 NaN
# 2               30/03/2022\n30/03/2023                                 NaN
# 3   26/01/2022\n31/03/2023\n31/03/2024  31/07/2022\n31/07/2023\n31/07/2024
# 4   01/02/2022\n31/03/2023\n31/03/2024  31/07/2022\n31/07/2023\n31/07/2024
# ..                                 ...                                 ...
# 94                 2021-01-08 00:00:00                                 NaN
# 95                 2021-01-08 00:00:00                                 NaN
# 96                 2022-11-24 00:00:00                 2022-11-24 00:00:00
# 97                 2022-11-24 00:00:00                                 NaN
# 98                 2022-05-24 00:00:00                                 NaN
#
#                     dateSoldeVersement notificationUE  pourcentageSubvention
# 0   30/09/2022\n30/09/2023\n30/09/2024            Non               1.000000
# 1                                  NaN            Non               1.000000
# 2               31/10/2022\n31/10/2023            Non               1.000000
# 3   31/01/2023\n31/01/2024\n31/01/2025            Non               1.000000
# 4   31/01/2023\n31/01/2024\n31/01/2025            Non               1.000000
# ..                                 ...            ...                    ...
# 94                                 NaN            Non               0.059939
# 95                                 NaN            Non               0.032990
# 96                 2022-11-24 00:00:00            Non               1.000000
# 97                 2022-11-24 00:00:00            Non               1.000000
# 98                                 NaN            Non               1.000000
#
# [99 rows x 16 columns]

# %%
# Calculer le pourcentage de NA dans chaque colonne
df2022.isna().mean() * 100
# Out:
# nomAttribuant             0.000000
# idAttribuant              0.000000
# dateConvention            0.000000
# referenceDecision         0.000000
# nomBénéficiaire           0.000000
# idBeneficiaire            0.000000
# objet                     0.000000
# montant                   0.000000
# nature                    0.000000
# conditionsVersement       0.000000
# conditionsVersement.1     0.000000
# datePremierVersement     20.202020
# dateDeuxiemeVersement    79.797980
# dateSoldeVersement       63.636364
# notificationUE            0.000000
# pourcentageSubvention     0.000000
# dtype: float64

# %%
df2021.isna().mean() * 100
# Out:
# nomAttribuant             0.000000
# idAttribuant              0.000000
# dateConvention            0.000000
# referenceDecision         0.000000
# nombeneficiaire           0.000000
# idbeneficiaire            0.000000
# objet                     0.000000
# montant                   0.000000
# nature                    0.000000
# conditionsVersement       0.000000
# datePremierVersement     40.000000
# datedeuxiemeVersement    90.000000
# dateVersementSolde       46.666667
# notificationUE            0.000000
# PourcentageSubvention     0.000000
# dtype: float64

# %%
df2020.isna().mean() * 100
# Out:
# nomAttribuant             0.000000
# idAttribuant              0.000000
# dateConvention            3.658537
# referenceDecision         0.000000
# nombeneficiaire           0.000000
# idbeneficiaire            0.000000
# objet                     0.000000
# montant                   0.000000
# nature                    0.000000
# conditionsVersement      26.829268
# datePremierVersement     46.341463
# datedeuxiemeVersement    87.804878
# dateVersementSolde       76.829268
# notificationUE            0.000000
# PourcentageSubvention     0.000000
# dtype: float64

# %%
df2019.isna().mean() * 100
# Out:
# nomAttribuant             0.000000
# idAttribuant              0.000000
# dateConvention            0.000000
# referenceDecision         0.000000
# nombeneficiaire           0.000000
# idbeneficiaire            3.448276
# objet                     0.000000
# montant                   0.000000
# nature                    0.000000
# conditionsVersement       0.000000
# datePremierVersement     24.137931
# datedeuxiemeVersement    85.057471
# dateVersementSolde       48.275862
# notificationUE            0.000000
# PourcentageSubvention     0.000000
# dtype: float64

# %% [markdown]
# #### Les valeurs manquantes
# Nous remarquons la plus part des valeurs manquantes concernent:
# datesPeriodeVersement
# dateDeuxiemeVersement
# dateSoldeVersement

# %% [markdown]
# #### Nettoyage de la base de données 2022

# %%
# Supprimer les doublons
df2022.drop_duplicates(inplace=True)

# Supprimer les colonnes inutiles
df2022.drop(['nomAttribuant','idAttribuant','dateConvention','nature','conditionsVersement.1','datePremierVersement','dateDeuxiemeVersement','dateSoldeVersement',
'notificationUE','pourcentageSubvention'], axis=1, inplace=True)

# Supprimer les lignes contenant des valeurs manquantes
df2022 = df2022.dropna()

# Convertir la colonne 'date' en type 'datetime'
df2022['referenceDecision'] = pd.to_datetime(df2022['referenceDecision'])

# Extraire l'année et le mois de chaque date et les stocker dans une nouvelle colonne 'annee_mois'
df2022['annee_mois'] = df2022['referenceDecision'].dt.strftime('%Y-%m')

# %%
df2022
# Out:
#    referenceDecision                                    nomBénéficiaire  \
# 0         2021-06-07     ASS PARRAINS PAR MILLE  ASS PARRAINS PAR MILLE
# 1         2021-12-10  BANQUE ALIMENTAIRE DE LA MAY  BANQUE ALIMENTAI...
# 2         2021-12-06                         ASSOCIATION LES DEUX RIVES
# 3         2022-01-03                                               UDAF
# 4         2022-01-03  ASSOCIATION DEPARTEMENTALE POUR LE LOGEMENT DE...
# ..               ...                                                ...
# 94        2021-12-09  COLLEGE PRIVE NOTRE DAME OGEC SAINT PIERRE LA ...
# 95        2021-12-09                       COLLEGE PRIVE SAINT NICOLAS
# 96        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 97        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 98        2022-03-07  L'AMICALE DU PERSONNEL DU CONSEIL DEPÄRTEMENTA...
#
#     idBeneficiaire                                              objet  \
# 0   39981222100048  Mise en œuvre d'actions de parrainage en direc...
# 1   39297142000022  Soutien technique et financier du Département ...
# 2   39313886200015  Partenariat entre le Département et l'associat...
# 3   77559377500031  UDAF met en place sur l'ensemble du départemen...
# 4   84223890900019  L'ADLJ met en place sur l'ensemble du départem...
# ..             ...                                                ...
# 94  78627559400046                                 Forfait d'Externat
# 95  78627883800044                                 Forfait d'Externat
# 96  47891394000019  4 axes sanitaires pour la protection des élevages
# 97  47891394000019                               prophylaxie annuelle
# 98  53099947300016                                      Arbre de Noël
#
#      montant                                conditionsVersement annee_mois
# 0   330000.0  Convention pour 3 ans du 21/06/2021 au 20/06/2...    2021-06
# 1    50000.0  Convention pour 1 an\nVersement en une seule f...    2021-12
# 2   120000.0  Convention pour 2 ans du 01/01/22 au 31/12/23 ...    2021-12
# 3   153000.0  Convention pour 3 ans du 01/01/2022 au 31/12/2...    2022-01
# 4   187500.0  Convention pour 3 ans du 01/01/2022 au 31/12/2...    2022-01
# ..       ...                                                ...        ...
# 94  231592.0                                        En une fois    2021-12
# 95  127334.0                                        En une fois    2021-12
# 96   42000.0  participation versée en une fois, sur présenta...    2021-12
# 97  112000.0  participation versée au GDS sur présentation d...    2021-12
# 98   74200.0   Cette subvention est composée de deux parts, ...    2022-03
#
# [99 rows x 7 columns]

# %% [markdown]
# #### Nettoyage de la base de données 2021

# %%
# Supprimer les doublons
df2021.drop_duplicates(inplace=True)
df2021 = df2021.rename(columns={'nombeneficiaire': 'nomBénéficiaire'})
# Supprimer les colonnes inutiles
df2021.drop(['nomAttribuant','idAttribuant','dateConvention','nature','datePremierVersement','datedeuxiemeVersement','dateVersementSolde',
'notificationUE','PourcentageSubvention'], axis=1, inplace=True)

# Supprimer les lignes contenant des valeurs manquantes
df2021 = df2021.dropna()

# Convertir la colonne 'date' en type 'datetime'
df2021['referenceDecision'] = pd.to_datetime(df2021['referenceDecision'])

# Extraire l'année et le mois de chaque date et les stocker dans une nouvelle colonne 'annee_mois'
df2021['annee_mois'] = df2021['referenceDecision'].dt.strftime('%Y-%m')

# %%
df2021
# Out:
#    referenceDecision                                    nomBénéficiaire  \
# 0         2020-12-10                  BANQUE ALIMENTAIRE DE LA MAYENNE
# 1         2020-12-10                                           ADAVIP
# 2         2020-12-10  FAMILLES RURALES FEDERATION DEPARTEMENTALE DE ...
# 3         2021-12-10                             MAISON DES ADOLESCENTS
# 4         2021-03-29                                             UDAF
# 5         2020-12-14                        ASSOCIATION BGE ANJOU MAINE
# 6         2020-12-10             MAYENNE COMPETENCES EMPLOI CAP EMPLOI
# 7         2021-03-08                                    CONDUITE AND CO
# 8         2020-12-10                 INALTA FORMATION  INALTA FORMATION
# 9         2020-12-10                                   LA PORTE OUVERTE
# 10        2020-12-10  ASSOCIATION DEPARTEMENTALE POUR LE LOGEMENT DE...
# 11        2020-12-10                           MAISON FAMILIALE RURALE
# 12        2020-06-29       COMMUNAUTE DE COMMUNES DU MONT DES AVALOIRS
# 13        2020-06-29        COMMUNAUTE DE COMMUNES DU PA DE MESLAY GREZ
# 14        2020-12-11  LE KIOSQUE CENTRE D ACTION CULTURELLE LE KIOSQ...
# 15        2019-07-08                                   FINAMUR  FINAMUR
# 16        2020-12-11                                   MAYENNE TOURISME
# 17        2021-05-31                                   MAYENNE TOURISME
# 18        2020-12-11                                      MAY'N LOISIRS
# 19        2020-12-11                                     ATMOSPHERES 53
# 20        2020-12-11                               ASSOCIATION POC POK
# 21        2021-06-07                             SCI BMC INVESTISSEMENT
# 22        2021-06-07                                          SCI CMTMC
# 23        2021-07-19                                           SCI ALCN
# 24        2021-07-19                 SARL Concept Rolland Développement
# 25        2021-10-04                                      SCI RC STOCKS
# 26        2021-12-06                                        SCI REBOURS
# 27        2021-12-07                                    ECOLE HOLBERTON
# 28        2021-01-25                                          SAS OUDON
# 29        2021-05-10                                       SAS METHADOM
#
#     idbeneficiaire                                              objet  \
# 0   39297142000022  Soutien technique et financier du département ...
# 1   38374884500039  Soutien technique et financier du département ...
# 2   41749487900048  Soutien technique et financier du département ...
# 3   13000087000035  Soutien financier au titre des actions de la M...
# 4   78625759200059  Partenariat entre l'association et le CD53 pou...
# 5   34041352500049  Accompagnement spécialisé des travailleurs ind...
# 6   44025826700028  Mise en œuvre d'actions d'accompagnement socio...
# 7   78846522700015                                 Auto-école sociale
# 8   84907857100023  Partenariat technique et financier pour la mis...
# 9   41266149800037  Soutien technique et financier du département ...
# 10  84223890900019  Actions favorisant l'accès et le maintien dans...
# 11  78624011900010  Formation et accompagnement des jeunes adultes...
# 12  20004218200010  convention de partenariat EPCI COVID en faveur...
# 13  20004218200010  convention de partenariat EPCI COVID en faveur...
# 14  38014684500025  Subvention de fonctionnement 2021 pour la sais...
# 15  34044670700044                     aide à l'immobilier industriel
# 16  38043867100048                     convention de partenariat 2021
# 17  38043867100048           avenant 2 à la convention de partenariat
# 18  20006177800011  subvention investissement dans le cadre de la ...
# 19  38159330000027  Subvention de fonctionnement 2021 : organisati...
# 20  48237845200023  Anne 2021 : 60 000 € pour le fonctionnement de...
# 21  89164970900013                     aide à l'immobilier industriel
# 22  84771857400019                     aide à l'immobilier industriel
# 23  88194698200017                     aide à l'immobilier industriel
# 24  42214796700026                     aide à l'immobilier industriel
# 25  88260963900019                     aide à l'immobilier industriel
# 26  34866676900016                     aide à l'immobilier industriel
# 27  82781682800012                       SUBVENTION DE FONCTIONNEMENT
# 28  79406074900023  Projet d'une unité de métahnisation Livré-la-T...
# 29  42486540000024  Projet d'une unité de métahnisation commune de...
#
#     montant                                conditionsVersement annee_mois
# 0     50000  Versement en une seule fois au début de l'anné...    2020-12
# 1     50000  Versement en une seule fois au début de l'anné...    2020-12
# 2     25000  Versement en une seule fois au début de l'anné...    2020-12
# 3     30000  Versement en une seule fois au début de l'anné...    2021-12
# 4     64125  Convention pour 4 ans de 2020 à 2023 et un tot...    2021-03
# 5    226278  Convention triennale 2021-2023 (montant global...    2020-12
# 6     43993  Convention du 01/01/2021 au 31/12/2021\n70% à ...    2020-12
# 7     74902  Convention du 01/04/2021au 31/03/2022\n70% à l...    2021-03
# 8     48800  Convention pour l'année 2021\n40% à la signatu...    2020-12
# 9     26500  Convention annuelle 2021\n80% à la signature d...    2020-12
# 10    27785  Convention annuelle 2021\n80% à la signature d...    2020-12
# 11    45000  Convention annuelle 2021\n80% à la signature d...    2020-12
# 12   131288  3 versements  au maximum sur présentation de p...    2020-06
# 13   112264  3 versements  au maximum sur présentation de p...    2020-06
# 14    40000    versement unique dès signature de la convention    2020-12
# 15   120000  versement unique sur présentation de pièces ju...    2019-07
# 16   980000  En 3 fois : 30% à la signature de la conventio...    2020-12
# 17      600                 à la notification de la convention    2021-05
# 18    50000  subvention investissement sur présentation fac...    2020-12
# 19   170000  70 % à la signature et le solde à réception de...    2020-12
# 20    90500  60 000 € dès signature de la convention, le so...    2020-12
# 21    61220  versement unique sur présentation de pièces ju...    2021-06
# 22    72140  versement unique sur présentation de pièces ju...    2021-06
# 23    76307  versement unique sur présentation de pièces ju...    2021-07
# 24    20091  versement unique sur présentation de pièces ju...    2021-07
# 25   120000  versement unique sur présentation de pièces ju...    2021-10
# 26   120000  versement unique sur présentation de pièces ju...    2021-12
# 27   100000                                  En plusieurs fois    2021-12
# 28   160000  La participation départementale est attribuée ...    2021-01
# 29    62500  La participation départementale est attribuée ...    2021-05

# %% [markdown]
# #### Nettoyage de la base de données 2020

# %%
# Supprimer les doublons
df2020.drop_duplicates(inplace=True)
df2020 = df2020.rename(columns={'nombeneficiaire': 'nomBénéficiaire'})
# Supprimer les colonnes inutiles
df2020.drop(['nomAttribuant','idAttribuant','dateConvention','nature','datePremierVersement','datedeuxiemeVersement','dateVersementSolde',
'notificationUE','PourcentageSubvention'], axis=1, inplace=True)
# supprimer la ligne qui contient "740000/AN"
df2020 = df2020.drop(df2020.loc[df2020['montant']=='740000/AN'].index)
# convertir la colonne 'montant' en type float
df2020['montant'] = pd.to_numeric(df2020['montant'])
# Supprimer les lignes contenant des valeurs manquantes
df2020 = df2020.dropna()

# Convertir la colonne 'date' en type 'datetime'
df2020['referenceDecision'] = pd.to_datetime(df2020['referenceDecision'])

# Extraire l'année et le mois de chaque date et les stocker dans une nouvelle colonne 'annee_mois'
df2020['annee_mois'] = df2020['referenceDecision'].dt.strftime('%Y-%m')

# %%
df2020
# Out:
#            referenceDecision  \
# 0  2019-12-11 19:00:00-05:00
# 1  2019-12-13 20:20:00-05:00
# 2  2019-12-12 19:00:00-05:00
# 3  2019-12-12 19:00:00-05:00
# 4  2019-12-12 19:00:00-05:00
# 5  2019-12-12 19:00:00-05:00
# 6  2019-12-12 19:00:00-05:00
# 7  2020-04-26 19:00:00-05:00
# 8  2020-03-29 19:00:00-05:00
# 9  2019-12-11 19:00:00-05:00
# 10 2019-06-16 19:00:00-05:00
# 11 2019-12-11 19:00:00-05:00
# 12 2019-12-11 19:00:00-05:00
# 13 2019-12-11 19:00:00-05:00
# 14 2019-12-11 19:00:00-05:00
# 15 2019-12-11 19:00:00-05:00
# 16 2019-12-12 19:00:00-05:00
# 17 2019-12-12 19:00:00-05:00
# 18 2020-03-08 19:00:00-05:00
# 19 2020-03-08 19:00:00-05:00
# 20 2020-03-08 19:00:00-05:00
# 21 2019-12-11 19:00:00-05:00
# 22 2019-12-11 19:00:00-05:00
# 23 2019-12-11 19:00:00-05:00
# 24 2020-01-12 19:00:00-05:00
# 25 2019-12-11 19:00:00-05:00
# 26 2019-12-11 19:00:00-05:00
# 27 2019-12-11 19:00:00-05:00
# 28 2019-12-11 19:00:00-05:00
# 29 2020-01-12 19:00:00-05:00
# 31 2019-12-11 19:00:00-05:00
# 32 2020-04-26 19:00:00-05:00
# 33 2019-12-11 19:00:00-05:00
# 34 2020-04-26 19:00:00-05:00
# 35 2019-12-11 19:00:00-05:00
# 36 2020-04-26 19:00:00-05:00
# 37 2019-12-11 19:00:00-05:00
# 38 2020-03-08 19:00:00-05:00
# 39 2020-03-08 19:00:00-05:00
# 40 2020-03-08 19:00:00-05:00
# 41 2019-03-31 19:00:00-05:00
# 42 2020-10-04 19:00:00-05:00
# 43 2020-11-08 19:00:00-05:00
# 44 2020-07-19 19:00:00-05:00
# 45 2020-05-17 19:00:00-05:00
# 46 2020-06-29 19:00:00-05:00
# 47 2020-09-27 19:00:00-05:00
# 48 2020-03-29 19:00:00-05:00
# 49 2020-03-29 19:00:00-05:00
# 50 2020-04-26 19:00:00-05:00
# 51 2020-03-29 19:00:00-05:00
# 52 2020-05-04 19:00:00-05:00
# 53 2020-06-28 19:00:00-05:00
# 54 2019-12-11 19:00:00-05:00
# 56 2020-12-09 19:00:00-05:00
# 57 2020-12-09 19:00:00-05:00
# 58 2020-12-09 19:00:00-05:00
# 59 2020-12-09 19:00:00-05:00
# 60 2020-12-10 19:00:00-05:00
#
#                                       nomBénéficiaire  idbeneficiaire  \
# 0   ASSOCIATION DES MAIRES ET ADJOINTS DE LA MAYENNE   44150648200021
# 1                   BANQUE ALIMENTAIRE DE LA MAYENNE   39297142000022
# 2                                            ADAVIP    38374884500039
# 3   FAMILLES RURALES FEDERATION DEPARTEMENTALE DE ...  41749487900048
# 4                                  INSER CONDUITE 53   49281401700025
# 5                                   LA PORTE OUVERTE   83403845700018
# 6                           MAISON FAMILIALE RURALE    78627058700011
# 7                                     ENVERGURE OUEST  34443825400049
# 8                    MAYENNE COMPETENCES EMPLOI CAP    44025826700028
# 9                        ASSOCIATION LECTURE EN TETE   41808871200017
# 10         COMITE DEPARTEMENTAL DU TOURISME MAYENNE    30698815500025
# 11         COMITE DEPARTEMENTAL DU TOURISME MAYENNE    30698815500025
# 12                         LE CARRE SCENE NATIONALE    30152308000036
# 13                                     ATMOSPHERES 53  38159330000027
# 14                                            POC POK  41411634300016
# 15                         LE KIOSQUE CENTRE D ACTION  38014684500025
# 16                                     MOTOCLUB ERNEE  81865403000019
# 17                       SOCIETE DES COURSES DE LAVAL  78834752400027
# 18                                        SAS FYBIMMO  84336323500014
# 19                                          SCI FAPIC  83432436000017
# 20                               SAS ALIMENTS GENOUEL  35121520700017
# 21                      ASSOCIATION LECTURE EN TETE    41808871200017
# 22                      MAISON DE L EUROPE EN MAYENNE  41266149800045
# 23         COMITE DEPARTEMENTAL DU TOURISME MAYENNE    30698815500025
# 24  ASSOCIATION LES AMIS DE LA BIBLIOTHEQUE DEPART...  30079785900034
# 25                         LE CARRE SCENE NATIONALE    30152308000036
# 26                                     ATMOSPHERES 53  38159330000027
# 27                                            POC POK  41411634300016
# 28                         LE KIOSQUE CENTRE D ACTION  38014684500025
# 29                    LE THEATRE, SCENE CONVENTIONNEE  20002554200016
# 31                        UNION SPORTIVE LAVALLOISE    78625651100027
# 32                       CAUE  CONSEIL D ARCHITECTURE  31755523300020
# 33                                     MOTOCLUB ERNEE  81865403000019
# 34                                         SAS MY PIE  81022553200029
# 35                                     MOTOCLUB ERNEE  81865403000019
# 36                                       SCI LC BECHE  85208234600028
# 37                       SOCIETE DES COURSES DE LAVAL  78834752400027
# 38                                       SAS FYB IMMO  84336323500014
# 39                                          SCI FAPIC  83432436000017
# 40                               SAS ALIMENTS GENOUEL  35121520700017
# 41                                    BPCE LEASE IMMO  33338431100069
# 42                                 SERIBASE INDUSTRIE  44263467100022
# 43                                           SCI BAMH  82746671500014
# 44                           CHAMBRE D'AGRICULTURE 53  18530045600026
# 45  COMITE DEPARTEMENTAL OLYMPIQUE ET SPORTIF MAYE...  41247528700014
# 46                              ECURIE OCEAN MAYENNE   44141931400022
# 47                     SASP STADE LAVALLOIS MAYENNE    38829190800027
# 48                                 LAVAL CYCLISME 53   51952594300014
# 49                        UNION SPORTIVE LAVALLOISE    78625651100027
# 50                                     MAY N LOISIRS   84887094500013
# 51                   MAYENNE CULTURE  MAYENNE CULTURE  30975508000053
# 52         COMITE DEPARTEMENTAL DU TOURISME MAYENNE    30698815500025
# 53          CHAMBRE DE METIERS ET DE L A L ARTISANAT   13002068800094
# 54                              LAVAL AGGLOMERATION    20008339200015
# 56             ESIEA  ECOLE SUPERIEURE D INFORMATIQUE  31134913800017
# 57    ECOLE NATIONALE SUPERIEURE  D' ARTS ET METIERS   19753472000010
# 58                   UNIVERSITE CATHOLIQUE DE L'OUEST  52132186900013
# 59  ECOLE SUPERIEURE DES TECHNIQUES AERONAUTIQUE E...  19753472000010
# 60                                      LAVAL VIRTUAL  44803276300014
#
#                                                 objet     montant  \
# 0                                      fonctionnement    42000.00
# 1   Soutien technique et financier du département ...    50000.00
# 2   Soutien technique et financier du département ...    50000.00
# 3   Soutien technique et financier du département ...    25000.00
# 4                                  Auto-école sociale    74902.00
# 5   Soutien technique et financier du département ...    26500.00
# 6   Formation et accompagnement des jeunes adultes...    45000.00
# 7   Mobilisation d'un référent de parcours inserti...    29200.00
# 8   Mise en œuvre d'actions d'accompagnement socio...    44945.00
# 9   Accompagnement de Lecture en tête sur l'opérat...    23000.00
# 10  Avenant 4 Actions de communication convention ...   200000.00
# 11                     Convention de partenariat 2020   985000.00
# 12  Avenant n°2 à la convention pluriannuelle d'ob...   133000.00
# 13  Subvention de fonctionnement : organisation du...   160000.00
# 14  50 000 € pour le fonctionnement de la saison d...    80500.00
# 15  Subvention de fonctionnement pour la saison ar...    40000.00
# 16  Subvention de fonctionnement et d'investisseme...   101747.00
# 17  Subvention d'investissement pour des travaux d...   100000.00
# 18  construction de 2 bâtiments (atelier et bureau...    89920.00
# 19  l’extension des bureaux et l’aménagement du pa...    35964.00
# 20                        construction de 4 bâtiments   120000.00
# 21  Accompagnement de Lecture en tête sur l'opérat...    23000.00
# 22                     Convention de partenariat 2020    10000.00
# 23                     Convention de partenariat 2020   985000.00
# 24                     Convention de partenariat 2020     7200.00
# 25  Avenant n°2 à la convention pluriannuelle d'ob...   133000.00
# 26  Subvention de fonctionnement : organisation du...   160000.00
# 27  50 000 € pour le fonctionnement de la saison d...    80500.00
# 28  Subvention de fonctionnement pour la saison ar...    40000.00
# 29                     Convention de partenariat 2020    50000.00
# 31                     Convention de partenariat 2020    23000.00
# 32  Avenant n°3 à la convention de partenariat d'o...   403686.00
# 33  Subvention de fonctionnement pour l'organisati...    50000.00
# 34  Agrandissement et réorganisation des locaux à ...    64885.00
# 35  Subvention d'investissement pour l'organisatio...    51747.00
# 36  extension et aménagement d'un bâtiment à Aron ...    46186.00
# 37  Subvention d'investissement pour des travaux d...   100000.00
# 38  construction de 2 bâtiments (atelier et bureau...    89920.00
# 39  l’extension des bureaux et l’aménagement du pa...    35964.00
# 40                        construction de 4 bâtiments   120000.00
# 41  construction d'un bâtiment PAI de la Lande à P...   120000.00
# 42  extension d'un bâtiment industriel à Château-G...   120000.00
# 43  extension d'un bâtiment (atelier et bureau) à ...    26960.00
# 44  Partenariat 2020 entre la Chambre d'agricultur...   380450.00
# 45  Partenariat 2020 : subvention de fonctionnemen...    59000.00
# 46  Subvention de fonctionnement pour l'organisati...    25000.00
# 47  Partenariat 2020-2021 au titre des missions d'...    60000.00
# 48                                   Partenariat 2020    22390.00
# 49                                   Partenariat 2020    23000.00
# 50  Subvention d’investissement pour le développem...    78280.00
# 51  Avenant n°1 à la convention d'objectifs et de ...    47500.00
# 52          Avenant n°1 à la convetion de partenariat   100000.00
# 53                          Convention de partenariat    41000.00
# 54  Avenant n°1 à la convention culturelle interco...  1200000.00
# 56       SUBVENTION DE FONCTIONNEMENT ET D'EQUIPEMENT   294054.15
# 57       SUBVENTION DE FONCTIONNEMENT ET D'EQUIPEMENT   137200.00
# 58       SUBVENTION DE FONCTIONNEMENT ET D'EQUIPEMENT    87500.00
# 59       SUBVENTION DE FONCTIONNEMENT ET D'EQUIPEMENT   117754.00
# 60  SUBVENTION DE FONCTIONNEMENT ET DU SALON LAVAL...   317774.80
#
#                                   conditionsVersement annee_mois
# 0   acompte à la signature solde apres bilan finan...    2019-12
# 1   Convention + avenant\nVersement 25 000 € en dé...    2019-12
# 2   Versement en une seule fois au début de l'anné...    2019-12
# 3   Versement en une seule fois au début de l'anné...    2019-12
# 4   Convention annuelle 2020 du 01/01/2020 au 31/0...    2019-12
# 5   Convention annuelle 2020\n80% à la signature d...    2019-12
# 6   Convention annuelle 2020\n80% à la signature d...    2019-12
# 7   Convention du 01/06/2020 au 31/12/2020\n80% à ...    2020-04
# 8   Convention du 01/05/2020 au 31/12/2020\n70% à ...    2020-03
# 9     versement unique dès signature de la convention    2019-12
# 10  Acompte de 50% à la production du plan d'actio...    2019-06
# 11  Acompte de 30% à la signature de la convention...    2019-12
# 12  70% à la signature de la convention, le solde ...    2019-12
# 13  25% avant signature de la convention, 50% à la...    2019-12
# 14  50 000 € dès signature de la convention, le so...    2019-12
# 15    versement unique dès signature de la convention    2019-12
# 16  en fonctionnement : 25 000 € après signature e...    2019-12
# 17  selon le reglèment financier sur présentation ...    2019-12
# 18  versement unique sur présentation de pièces ju...    2020-03
# 19  versement unique sur présentation de pièces ju...    2020-03
# 20  versement unique sur présentation de pièces ju...    2020-03
# 21    versement unique dès signature de la convention    2019-12
# 22    versement unique dès signature de la convention    2019-12
# 23  Acompte de 30% à la signature de la convention...    2019-12
# 24    versement unique dès signature de la convention    2020-01
# 25  70% à la signature de la convention, le solde ...    2019-12
# 26  25% avant signature de la convention, 50% à la...    2019-12
# 27  50 000 € dès signature de la convention, le so...    2019-12
# 28    versement unique dès signature de la convention    2019-12
# 29    versement unique dès signature de la convention    2020-01
# 31    versement unique dès signature de la convention    2019-12
# 32  30% en janvier, 30% dès la signature de l'aven...    2020-04
# 33  25 000 € après signature et le solde après l'é...    2019-12
# 34  versement unique sur présentation de pièces ju...    2020-04
# 35  selon le réglement financier sur présentation ...    2019-12
# 36  versement unique sur présentation de pièces ju...    2020-04
# 37  selon le reglèment financier sur présentation ...    2019-12
# 38  versement unique sur présentation de pièces ju...    2020-03
# 39  versement unique sur présentation de pièces ju...    2020-03
# 40  versement unique sur présentation de pièces ju...    2020-03
# 41  versement unique sur présentation de pièces ju...    2019-03
# 42  versement unique sur présentation de pièces ju...    2020-10
# 43  versement unique sur présentation de pièces ju...    2020-11
# 44  70 % à la signature de la convention le solde ...    2020-07
# 45  55 000 € après signature et 4 000 € après réce...    2020-05
# 46  12 500 € à la signature de la convention, 12 5...    2020-06
# 47  30 000 € dès la signature et  solde 30 000 € s...    2020-09
# 48                    A la signature de la convention    2020-03
# 49                    A la signature de la convention    2020-03
# 50  3 versements max au vu des dépenses réalisées ...    2020-04
# 51  acompte correspondant au prux de la phase 1 de...    2020-03
# 52   versement unique à la signature de la convention    2020-05
# 53  versement unique sur présentation de pièces ju...    2020-06
# 54  50% d'acompte en 2020, solde à partir de 2021 ...    2019-12
# 56                                  En plusieurs fois    2020-12
# 57                                  En plusieurs fois    2020-12
# 58                                  En plusieurs fois    2020-12
# 59                                  En plusieurs fois    2020-12
# 60                                  En plusieurs fois    2020-12

# %% [markdown]
# #### Nettoyage de la base de données 2019

# %%
# Supprimer les doublons
df2019.drop_duplicates(inplace=True)
df2019 = df2019.rename(columns={'nombeneficiaire': 'nomBénéficiaire'})
# Supprimer les colonnes inutiles
df2019.drop(['nomAttribuant','idAttribuant','dateConvention','nature','datePremierVersement','datedeuxiemeVersement','dateVersementSolde',
'notificationUE','PourcentageSubvention'], axis=1, inplace=True)

# Supprimer les lignes contenant des valeurs manquantes
df2019 = df2019.dropna()

# Convertir la colonne 'date' en type 'datetime'
df2019['referenceDecision'] = pd.to_datetime(df2019['referenceDecision'])
# Extraire l'année et le mois de chaque date et les stocker dans une nouvelle colonne 'annee_mois'
df2019['annee_mois'] = df2019['referenceDecision'].dt.strftime('%Y-%m')

# %%
df2022
# Out:
#    referenceDecision                                    nomBénéficiaire  \
# 0         2021-06-07     ASS PARRAINS PAR MILLE  ASS PARRAINS PAR MILLE
# 1         2021-12-10  BANQUE ALIMENTAIRE DE LA MAY  BANQUE ALIMENTAI...
# 2         2021-12-06                         ASSOCIATION LES DEUX RIVES
# 3         2022-01-03                                               UDAF
# 4         2022-01-03  ASSOCIATION DEPARTEMENTALE POUR LE LOGEMENT DE...
# ..               ...                                                ...
# 94        2021-12-09  COLLEGE PRIVE NOTRE DAME OGEC SAINT PIERRE LA ...
# 95        2021-12-09                       COLLEGE PRIVE SAINT NICOLAS
# 96        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 97        2021-12-10  GPT DEFENSE SANITAIRE BETAIL DE LA MAYENNE GPT...
# 98        2022-03-07  L'AMICALE DU PERSONNEL DU CONSEIL DEPÄRTEMENTA...
#
#     idBeneficiaire                                              objet  \
# 0   39981222100048  Mise en œuvre d'actions de parrainage en direc...
# 1   39297142000022  Soutien technique et financier du Département ...
# 2   39313886200015  Partenariat entre le Département et l'associat...
# 3   77559377500031  UDAF met en place sur l'ensemble du départemen...
# 4   84223890900019  L'ADLJ met en place sur l'ensemble du départem...
# ..             ...                                                ...
# 94  78627559400046                                 Forfait d'Externat
# 95  78627883800044                                 Forfait d'Externat
# 96  47891394000019  4 axes sanitaires pour la protection des élevages
# 97  47891394000019                               prophylaxie annuelle
# 98  53099947300016                                      Arbre de Noël
#
#      montant                                conditionsVersement annee_mois
# 0   330000.0  Convention pour 3 ans du 21/06/2021 au 20/06/2...    2021-06
# 1    50000.0  Convention pour 1 an\nVersement en une seule f...    2021-12
# 2   120000.0  Convention pour 2 ans du 01/01/22 au 31/12/23 ...    2021-12
# 3   153000.0  Convention pour 3 ans du 01/01/2022 au 31/12/2...    2022-01
# 4   187500.0  Convention pour 3 ans du 01/01/2022 au 31/12/2...    2022-01
# ..       ...                                                ...        ...
# 94  231592.0                                        En une fois    2021-12
# 95  127334.0                                        En une fois    2021-12
# 96   42000.0  participation versée en une fois, sur présenta...    2021-12
# 97  112000.0  participation versée au GDS sur présentation d...    2021-12
# 98   74200.0   Cette subvention est composée de deux parts, ...    2022-03
#
# [99 rows x 7 columns]

# %%
import dash
import dash_bootstrap_components as dbc
import dash_core_components as dcc
import dash_html_components as html,dash_table
import plotly.graph_objs as go
import plotly.express as px
from dash.dependencies import Input, Output

# Agréger le montant total de subvention par année
df_agg1 = df2022.groupby(df2022['annee_mois'])['montant'].sum().reset_index()
df_agg2 = df2021.groupby(df2021['annee_mois'])['montant'].sum().reset_index()
df_agg3 = df2020.groupby(df2020['annee_mois'])['montant'].sum().reset_index()
df_agg4 = df2019.groupby(df2019['annee_mois'])['montant'].sum().reset_index()

# Agréger les montants de subvention par bénéficiaire
df_aggSub1 = df2022.groupby('nomBénéficiaire').sum().reset_index()
df_aggSub2 = df2021.groupby('nomBénéficiaire').sum().reset_index()
df_aggSub3 = df2020.groupby('nomBénéficiaire').sum().reset_index()
df_aggSub4 = df2019.groupby('nomBénéficiaire').sum().reset_index()

# Création du dictionnaire contenant les dataframes
dataframes1 = {
    'df_aggSub1': df_aggSub1,
    'df_aggSub2': df_aggSub2,
    'df_aggSub3': df_aggSub3,
    'df_aggSub4': df_aggSub4
}
# création du graphiques 1


# création du graphiques 1
graph1 = dcc.Graph(
    id='graph1',
    figure={
        'data': [
            go.Scatter(
                x=df_agg1['annee_mois'],
                y=df_agg1['montant'],
                mode='lines+markers',
                name = '2022'
            ),
            go.Scatter(
                x=df_agg2['annee_mois'],
                y=df_agg2['montant'],
                mode='lines+markers',
                name = '2021'
            ),
            go.Scatter(
                x=df_agg3['annee_mois'],
                y=df_agg3['montant'],
                mode='lines+markers',
                name = '2020'
            ),
            go.Scatter(
                x=df_agg4['annee_mois'],
                y=df_agg4['montant'],
                mode='lines+markers',
                name = '2019'
            )
        ],
        'layout': go.Layout(
            title='Comparaison des montants de subventions entre les années',
            xaxis={'title': 'Années'},
            yaxis={'title': 'Le montant de subvention en euros'}
        )
    }
)

# Création du graphique 2

# Création du dataframe agrégé
dfagg2022 = df2022.agg({'montant': 'sum'})
dfagg2021 = df2021.agg({'montant': 'sum'})
dfagg2020 = df2020.agg({'montant': 'sum'})
dfagg2019 = df2019.agg({'montant': 'sum'})
Yaxis=[dfagg2019['montant'],dfagg2020['montant'],dfagg2021['montant'],dfagg2022['montant']]
# Création du graphique
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']  # Liste de couleurs
fig = px.histogram( x=['2019','2020','2021','2022'], y=Yaxis,title='Montants totaux pour chaque année',
                   color_discrete_sequence=['#1f77b4'], template='plotly_white')

# Personnalisation de l'histogramme

fig.update_traces(marker=dict(color=colors,line=dict(color=colors, width=1.5)),text=Yaxis)

fig.update_layout(
    xaxis=dict(title='Années', tickmode='linear', dtick=1),
    yaxis=dict(title='Montant total en euros', gridcolor='#f0f0f0'),
    bargap=0.1,
    margin=dict(l=40, r=40, t=40, b=40),
    plot_bgcolor='#ffffff'
)
graph2 = dcc.Graph(id='graph2', figure=fig)

# création du graphiques 3

# Création du graphique initial
fig = px.bar(df_aggSub1, x='nomBénéficiaire', y='montant', title='Montants de subventions accordées aux associations en 2022',
            color_discrete_sequence=['#1f77b4'], template='plotly_white')
graph3 = dcc.Graph(id='graph3', figure=fig)

# création de la mise en page
app = dash.Dash(external_stylesheets=[dbc.themes.BOOTSTRAP])
# Création du Dropdown
dropdown1 = dcc.Dropdown(
        id='dropdown1',
        options=[
            {'label': 'Montants de subventions accordées aux associations en 2022', 'value': 'df_aggSub1'},
            {'label': 'Montants de subventions accordées aux associations en 2021', 'value': 'df_aggSub2'},
            {'label': 'Montants de subventions accordées aux associations en 2020', 'value': 'df_aggSub3'},
            {'label': 'Montants de subventions accordées aux associations en 2019', 'value': 'df_aggSub4'}
        ],
        value='df_aggSub1'
    )
# Callback pour mettre à jour le graphique
@app.callback(
    Output('graph3', 'figure'),
    Input('dropdown1','value')
)
def update_graph3(value):
    df = dataframes1[value]
    fig = px.bar(df, x='nomBénéficiaire', y='montant')

    # Ajouter le nom de l'axe des abscisses (axe x)
    fig.update_xaxes(title_text="Bénéficiaire")

    # Ajouter le nom de l'axe des ordonnées (axe y)
    fig.update_yaxes(title_text="Montant en euros")

    # Ajouter la légende
    fig.update_layout(
        legend=dict(
            title="Légende",
            title_font=dict(size=14),
            font=dict(size=12)
        )
    )

    # Ajouter le titre
    fig.update_layout(
        title={
            'x': 0.5,
            'y': 0.95,
            'xanchor': 'center',
            'yanchor': 'top',
            'font': dict(size=16)
        }
    )

    return fig






# Creation du tableau

# Création du dictionnaire contenant les dataframes
dataframes2 = {
    'df_agg2022': df2022,
    'df_agg2021': df2021,
    'df_agg2020': df2020,
    'df_agg2019': df2019
}

dropdown2 = dcc.RadioItems(
         id='annees',
        options=[
            {'label': '2022', 'value': 'df_agg2022'},
            {'label': '2021', 'value': 'df_agg2021'},
            {'label': '2020', 'value': 'df_agg2020'},
            {'label': '2019', 'value': 'df_agg2019'}
        ],
        value='df_agg2022',inline=True
    )

# Création du tableau
table_columns = [
    {'name': 'Bénéficiaire', 'id': 'nomBénéficiaire'},
    {'name': 'Mois', 'id': 'annee_mois'},
    {'name': 'Montant', 'id': 'montant'},
    {'name': 'Objet de la subvention', 'id': 'objet'}
]
table = dash_table.DataTable(
    id='table',
    columns=table_columns,
    data=[]
)

dropdown3 = dcc.Dropdown(
        id='beneficiaire',
        options=[],
        multi=True
    )

@app.callback(
    Output('beneficiaire', 'options'),
    Input('annees', 'value')
    
)
def update_beneficiaires(dataframe_name):
    beneficiaires = dataframes2[dataframe_name]['nomBénéficiaire'].unique()
    options = [{'label': beneficiaire, 'value': beneficiaire} for beneficiaire in beneficiaires]
    return options


@app.callback(
    Output('table', 'data'),
    Input('beneficiaire', 'value'),
    Input('annees', 'value')
)
def update_table(beneficiaires, dataframe_name):
    df = dataframes2[dataframe_name]
    df_filtered = df[df['nomBénéficiaire'].isin(beneficiaires)]
    group_df = df_filtered.groupby(['annee_mois', 'nomBénéficiaire', 'objet'], as_index=False).sum()
    total_df = df_filtered.groupby('nomBénéficiaire', as_index=False).sum()
    total_df['annee_mois'] = 'Total'
    total_df['objet'] = 'Total'
    return group_df.append(total_df, ignore_index=True).to_dict('records')

# ajout d'un logo et d'un texte
logo1 = html.Div(
    children=[
    html.Img(src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcT5Tx5qu9iJNEte1mOE70YdfocZ1o7ahHJ67C0aHv_I09kPwvmvcBG2CViWNvQ&s', style={'height': '70px'})
    ]
)

logo2 = html.Div(
    children=[
    html.Img(src='https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTyS_biJwfe4rK9ImWtDEuYFG73nu6Py2RigCQh-OuKHmX6rKQn8JGQN8lvgw&s', style={'height': '40px','align':'right'})
    ]
)

titre = html.Div(
    html.H1(children='Tableau de Bord de l\'attribution des subventions du Conseil départemental de la Mayenne', style={'margin': 'auto', 'textAlign': 'center'})
)


titre1 = html.Div(
    html.H6(children='Montants de subventions accordées aux associations en années', style={'margin': 'auto', 'textAlign': 'center'})
)
titre2 = html.Div(
    html.H6(children='Tableau des montants de subventions par mois, bénéficiaire et objet', style={'margin': 'auto', 'textAlign': 'center'})
)
text= html.Div(
    html.H5(children='©2023ngambmoussa', style={'margin': 'auto'})
)
def make_break(num_breaks):
    br_list = [html.Br()] * num_breaks
    return br_list
# Out:
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:3: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:4: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html,dash_table
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:4: UserWarning:
# The dash_table package is deprecated. Please replace
# `import dash_table` with `from dash import dash_table`
#
# Also, if you're using any of the table format helpers (e.g. Group), replace
# `from dash_table.Format import Group` with
# `from dash.dash_table.Format import Group`
#   import dash_html_components as html,dash_table
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:16: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aggSub1 = df2022.groupby('nomBénéficiaire').sum().reset_index()
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aggSub2 = df2021.groupby('nomBénéficiaire').sum().reset_index()
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:18: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aggSub3 = df2020.groupby('nomBénéficiaire').sum().reset_index()
# /var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py:19: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_aggSub4 = df2019.groupby('nomBénéficiaire').sum().reset_index()

# %%
app.layout = html.Div([
    html.Div([
        dbc.Row([
        dbc.Col(logo1, width=2.5),
        dbc.Col(titre, width=15),
            *make_break(3),
    ], className='header'),
        dbc.Row([
        dbc.Col(graph1, width=6),
        dbc.Col(graph2, width=6)
    ], className='row'),
       *make_break(3),
       dbc.Row([
        dbc.Col([titre1,*make_break(1),dropdown1,graph3], md=6),
        dbc.Col([titre2,*make_break(1),dropdown2,dropdown3,table], md=6)
    ], className='row'),
        *make_break(3),
        dbc.Row([
            dbc.Col([logo2,text])
        ])
    ])
])

if __name__ == '__main__':
    app.run_server(debug=False, dev_tools_ui=False, dev_tools_props_check=False)
# Out:
# Dash is running on http://127.0.0.1:8050/
#
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:8050
# Press CTRL+C to quit
# 127.0.0.1 - - [19/May/2023 13:01:01] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2023 13:01:02] "GET /_dash-component-suites/dash/dcc/async-graph.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2023 13:01:02] "GET /_dash-component-suites/dash/dash_table/async-highlight.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2023 13:01:02] "GET /_dash-component-suites/dash/dcc/async-dropdown.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2023 13:01:02] "GET /_dash-component-suites/dash/dash_table/async-table.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2023 13:01:03] "GET /_dash-component-suites/dash/dcc/async-plotlyjs.js HTTP/1.1" 304 -
# 127.0.0.1 - - [19/May/2023 13:01:03] "GET /_dash-layout HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2023 13:01:03] "GET /_dash-dependencies HTTP/1.1" 200 -
# 127.0.0.1 - - [19/May/2023 13:01:04] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1274, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py", line 215, in update_table
#     df_filtered = df[df['nomBénéficiaire'].isin(beneficiaires)]
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py", line 5563, in isin
#     result = algorithms.isin(self._values, values)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py", line 459, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [NoneType]
# 127.0.0.1 - - [19/May/2023 13:01:05] "POST /_dash-update-component HTTP/1.1" 500 -
# 127.0.0.1 - - [19/May/2023 13:01:05] "POST /_dash-update-component HTTP/1.1" 200 -
# Exception on /_dash-update-component [POST]
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 2525, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1822, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1820, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/flask/app.py", line 1796, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/dash.py", line 1274, in dispatch
#     ctx.run(
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/dash/_callback.py", line 440, in add_context
#     output_value = func(*func_args, **func_kwargs)  # %% callback invoked %%
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/var/folders/z5/z205q_gs53g35dpt2nk3cq2w0000gn/T/ipykernel_20476/2412327677.py", line 215, in update_table
#     df_filtered = df[df['nomBénéficiaire'].isin(beneficiaires)]
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py", line 5563, in isin
#     result = algorithms.isin(self._values, values)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/algorithms.py", line 459, in isin
#     raise TypeError(
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [NoneType]
# 127.0.0.1 - - [19/May/2023 13:01:07] "POST /_dash-update-component HTTP/1.1" 500 -
